# %%
from dna_features_viewer import GraphicFeature, GraphicRecord
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pal = sns.color_palette('viridis')
hexx = pal.as_hex()
display(hexx)
# NS 1 '#46327e', 
# VP 1 '#4ac16d',
# Hypothetical protein '#365c8d'
# '#277f8e', '#1fa187',  
# repeat = '#a0da39'
# Out:
# ['#46327e', '#365c8d', '#277f8e', '#1fa187', '#4ac16d', '#a0da39']

# %%
#Lisnice11_NODE_124_length_4325_cov_60.507042
features=[
    GraphicFeature(start=713, end=2266, strand=+1, color="#46327e",
                   label="NS1"),
    GraphicFeature(start=606, end=1328, strand=+1, color="#365c8d",
                   label="HP1"),
    GraphicFeature(start=2280, end=2930, strand=+1, color="#365c8d",
                   label="HP2"),
    GraphicFeature(start=2352, end=4604, strand=-1, color="#4ac16d",
                   label="SP"),
    GraphicFeature(start=3935, end=4423, strand=-1, color="#365c8d",
                   label="HP3"),
    GraphicFeature(start=4596, end=4827, strand=-1, color="#a0da39",
                   label="Repeat"),
    GraphicFeature(start=39, end=270, strand=+1, color="#a0da39",
                   label="Repeat")

]
record = GraphicRecord(sequence_length=4865, features=features)
ax, _ = record.plot(figure_width=10)
ax.set_title("Bee densovirus 1 (4 865bp)", loc='center', weight='bold')
ax.figure.savefig("Densovirus1.png", dpi = 300)

# %%
#Libechov6_NODE_130_length_4790_cov_288.941226_1
features=[
    GraphicFeature(start=1534, end=3222, strand=+1, color="#4ac16d",
                   label="SP-B"),
    GraphicFeature(start=4042, end=4479, strand=+1, color="#365c8d",
                   label="HP1"),
    GraphicFeature(start=755, end=1714, strand=+1, color="#4ac16d",
                   label="SP-A"),
    GraphicFeature(start=3253, end=4887, strand=-1, color="#46327e",
                   label="NS1"),
    GraphicFeature(start=4023, end=4841, strand=-1, color="#46327e",
                   label="NS2"),
    GraphicFeature(start=4844, end=5257, strand=-1, color="#365c8d",
                   label="HP2"),
    GraphicFeature(start=15, end=169, strand=+1, color="#a0da39",
                   label="Repeat"),
    GraphicFeature(start=5447, end=5601, strand=-1, color="#a0da39",
                   label="Repeat")
]
record = GraphicRecord(sequence_length=5601, features=features)
ax, _ = record.plot(figure_width=10)
ax.set_title("Bee densovirus 2 (5 601bp)", loc='center', weight='bold')
ax.figure.savefig("Densovirus2.png", dpi = 300)

# %%
#Libechov6_NODE_130_length_4790_cov_288.941226_1
#REVERSED
features=[
    GraphicFeature(start=3888, end=4847, strand=-1, color="#4ac16d",
                   label="SP-B"),
    GraphicFeature(start=1123, end=1560, strand=-1, color="#365c8d",
                   label="HP1"),
    GraphicFeature(start=2380, end=4068, strand=-1, color="#4ac16d",
                   label="SP-A"),
    GraphicFeature(start=715, end=2349, strand=+1, color="#46327e",
                   label="NS1"),
    GraphicFeature(start=761, end=1579, strand=+1, color="#46327e",
                   label="NS2"),
    GraphicFeature(start=345, end=758, strand=+1, color="#365c8d",
                   label="HP2"),
    GraphicFeature(start=1, end=155, strand=+1, color="#a0da39",
                   label="Repeat"),
    GraphicFeature(start=5433, end=5587, strand=-1, color="#a0da39",
                   label="Repeat")
]
record = GraphicRecord(sequence_length=5601, features=features)
ax, _ = record.plot(figure_width=10)
ax.set_title("Bee densovirus 2 (5 601bp)", loc='center', weight='bold')
ax.figure.savefig("Densovirus2_reversed.png", dpi = 300)

# %%
#BP26_NODE_7_length_3632_cov_1_826545
features=[
    GraphicFeature(start=148, end=1758, strand=+1, color="#4ac16d",
                   label="SP"),
    GraphicFeature(start=3027, end=3512, strand=-1, color="#46327e",
                   label="NS"),
    GraphicFeature(start=1761, end=2780, strand=-1, color="#46327e",
                   label="NS1"),
    GraphicFeature(start=2, end=77, strand=+1, color="#a0da39",
                   label="Repeat"),
    GraphicFeature(start=3557, end=3632, strand=-1, color="#a0da39",
                   label="Repeat")
]
record = GraphicRecord(sequence_length=3632, features=features)
ax, _ = record.plot(figure_width=10)
ax.set_title("Bee densovirus 3 (3 632bp)", loc='center', weight='bold')
ax.figure.savefig("Densovirus3.png", dpi = 300)

# %%
#BP26_NODE_7_length_3632_cov_1_826545_
#REVERSED
features=[
    GraphicFeature(start=1875, end=3485, strand=-1, color="#4ac16d",
                   label="SP"),
    GraphicFeature(start=853, end=1872, strand=+1, color="#46327e",
                   label="NS"),
    GraphicFeature(start=121, end=606, strand=+1, color="#46327e",
                   label="NS1"),
    GraphicFeature(start=1, end=76, strand=+1, color="#a0da39",
                   label="Repeat"),
    GraphicFeature(start=3556, end=3631, strand=-1, color="#a0da39",
                   label="Repeat")
]
record = GraphicRecord(sequence_length=3632, features=features)
ax, _ = record.plot(figure_width=10)
ax.set_title("Bee densovirus 3 (3 632bp)", loc='center', weight='bold')
ax.figure.savefig("Densovirus3_reversed.png", dpi = 300)

# %%
#BeeP-44-2013_scaffolds_NODE_11_length_5160_cov_56_990163
features=[
    GraphicFeature(start=430, end=1452, strand=+1, color="#365c8d",
                   label="HP2"),
    GraphicFeature(start=15, end=437, strand=+1, color="#365c8d",
                   label="HP1"),
    GraphicFeature(start=693, end=2225, strand=+1, color="#46327e",
                   label="NS1"),
    GraphicFeature(start=4479, end=4976, strand=+1, color="#365c8d",
                   label="HP3"),
    GraphicFeature(start=4507, end=4929, strand=-1, color="#365c8d",
                   label="HP4"),
    GraphicFeature(start=2234, end=5056, strand=-1, color="#4ac16d",
                   label="SP")
]
record = GraphicRecord(sequence_length=5160, features=features)
ax, _ = record.plot(figure_width=10)
ax.set_title("Bee densovirus 4 (5 160bp)", loc='center', weight='bold')
ax.figure.savefig("Densovirus4.png", dpi = 300)

# %%
#BeeP-38-2013_scaffolds_NODE_14_length_3910_cov_16_664409
features=[
    GraphicFeature(start=344, end=1885, strand=+1, color="#46327e",
                   label="NS1"),
    GraphicFeature(start=324, end=992, strand=+1, color="#365c8d",
                   label="HP"),
    GraphicFeature(start=1954, end=3681, strand=-1, color="#4ac16d",
                   label="SP")
]
record = GraphicRecord(sequence_length=3910, features=features)
ax, _ = record.plot(figure_width=10)
ax.set_title("Bee densovirus 5 (3 910bp)", loc='center', weight='bold')
ax.figure.savefig("Densovirus5.png", dpi = 300)

# %%
#BeeCelsaC5_NODE_137_length_5058_cov_1759.256374
features=[
    GraphicFeature(start=127, end=819, strand=+1, color="#46327e",
                   label="NS"),
    GraphicFeature(start=823, end=1611, strand=+1, color="#46327e",
                   label="NS2"),
    GraphicFeature(start=3095, end=3511, strand=+1, color="#365c8d",
                   label="HP2"),
    GraphicFeature(start=816, end=2414, strand=+1, color="#46327e",
                   label="NS1"),
    GraphicFeature(start=4215, end=4955, strand=-1, color="#4ac16d",
                   label="SP-B"),
    GraphicFeature(start=2411, end=4231, strand=-1, color="#4ac16d",
                   label="SP-A"),
    GraphicFeature(start=1055, end=1630, strand=-1, color="#365c8d",
                   label="HP1"),
    GraphicFeature(start=1, end=77, strand=+1, color="#a0da39",
                   label="Repeat"),
    GraphicFeature(start=4982, end=5058, strand=-1, color="#a0da39",
                   label="Repeat")
]
record = GraphicRecord(sequence_length=5058, features=features)
ax, _ = record.plot(figure_width=10)
ax.set_title("Bee densovirus 6 (5 058bp)", loc='center', weight='bold')
ax.figure.savefig("Densovirus6.png", dpi = 300)

# %%
#BeeCelsaB3_NODE_93_length_4841_cov_22.532534
features=[
    GraphicFeature(start=415, end=1269, strand=+1, color="#46327e",
                   label="NS2"),
    GraphicFeature(start=435, end=2114, strand=+1, color="#46327e",
                   label="NS1"),
    GraphicFeature(start=3854, end=4618, strand=-1, color="#4ac16d",
                   label="SP-B"),
    GraphicFeature(start=2140, end=3861, strand=-1, color="#4ac16d",
                   label="SP-A")

]
record = GraphicRecord(sequence_length=4841, features=features)
ax, _ = record.plot(figure_width=10)
ax.set_title("Bee densovirus 7 (4 841bp)", loc='center', weight='bold')
ax.figure.savefig("Densovirus7.png", dpi = 300)

# %%
#BeeCelsaB3_NODE_77_length_6023_cov_29.280525
features=[
    GraphicFeature(start=1036, end=1743, strand=+1, color="#365c8d",
                   label="HP1"),
    GraphicFeature(start=1733, end=3025, strand=+1, color="#46327e",
                   label="NS1"),
    GraphicFeature(start=252, end=1028, strand=+1, color="#365c8d",
                   label="HP2"),
    GraphicFeature(start=1167, end=1709, strand=+1, color="#365c8d",
                   label="HP3"),
    GraphicFeature(start=3036, end=5897, strand=-1, color="#4ac16d",
                   label="SP")

]
record = GraphicRecord(sequence_length=6023, features=features)
ax, _ = record.plot(figure_width=10)
ax.set_title("Bee densovirus 8 (6 023bp)", loc='center', weight='bold')
ax.figure.savefig("Densovirus8.png", dpi = 300)

# %%
#BeeCelsaA5_NODE_153_length_4798_cov_87.918154
features=[
    GraphicFeature(start=343, end=939, strand=+1, color="#365c8d",
                   label="HP1"),
    GraphicFeature(start=1000, end=2508, strand=+1, color="#46327e",
                   label="NS1"),
    GraphicFeature(start=941, end=1738, strand=+1, color="#46327e",
                   label="NS2"),
    GraphicFeature(start=4239, end=4751, strand=+1, color="#365c8d",
                   label="HP2"),
    GraphicFeature(start=2555, end=5107, strand=-1, color="#4ac16d",
                   label="SP"),
    GraphicFeature(start=67, end=235, strand=+1, color="#a0da39",
                   label="Repeat"),
    GraphicFeature(start=5034, end=5202, strand=-1, color="#a0da39",
                   label="Repeat")
]
record = GraphicRecord(sequence_length=5202, features=features)
ax, _ = record.plot(figure_width=10)
ax.set_title("Bee densovirus 9 (5 202bp)", loc='center', weight='bold')
ax.figure.savefig("Densovirus9.png", dpi = 300)
